# %%
# Mathematics for Machine learning
# Linear algebra

# Previously, all parameters are worked upon operation by operation. LA is needed as it gives tool & techniques to work on huge amount of data
# Data representation done by vectors (single data points), metrics (multiple data points)
# Parallel computing : Intead of using loops to compute something like BMI (example, it does in one go). Multiple threads are opened

# Vectors: Ordered list of numbers
# Example: list of colors, made by 3 numbers

# %%
#
