# %%
s = "   Python for AI  "
print(s.strip())
print(s.lower())
print(s.split())
# Out:
# Python for AI
#    python for ai
# ['Python', 'for', 'AI']

# %%
list = [1,2,3,4,5]
print(sum(list))
print(max(list))
print([n*2 for n in list])
# Out:
# 15
# 5
# [2, 4, 6, 8, 10]

# %%
dict = {"title": "A man called ove", "author": "Fredrik Backman", "year": "2022"}
print(f"{dict['title']} by {dict['author']} ({dict['year']})")
# Out:
# A man called ove by Fredrik Backman (2022)

# %%
marks = [55, 72, 91, 38, 66, 72]
print(sum(1 for m in marks if m>=60))
print(sum(1 for m in marks if m>=85))
print(set(marks))
# Out:
# 4
# 1
# {66, 38, 72, 55, 91}

# %%
values = [1, 2, 2, 3, 3, 3]
unique = set(values)
print("Example 34:", unique)

# Example 35: membership is fast and readable
print("Example 35:", 2 in unique, 99 in unique)
# Out:
# Example 34: {1, 2, 3}
# Example 35: True False
